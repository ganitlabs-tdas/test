# %%
import pandas as pd
import numpy as np
import datetime

# %% [markdown]
# import pandas as pd
# import numpy as np
# import random
# import datetime
# import matplotlib.pyplot as plt
# from matplotlib.colors import LogNorm
# import math
# import seaborn as sns

# %%
#HI, this is Trayan

# %%
#Hi, this is ganitlabs_td

# %%
todays_date = datetime.datetime.now().date()
idx = pd.date_range(todays_date, periods=10, freq='D')
col = ['col_1', 'col_2', 'col_3']

df = pd.DataFrame(index=idx, columns=col) 
print(df)
# Out:
#            col_1 col_2 col_3
# 2021-04-20   NaN   NaN   NaN
# 2021-04-21   NaN   NaN   NaN
# 2021-04-22   NaN   NaN   NaN
# 2021-04-23   NaN   NaN   NaN
# 2021-04-24   NaN   NaN   NaN
# 2021-04-25   NaN   NaN   NaN
# 2021-04-26   NaN   NaN   NaN
# 2021-04-27   NaN   NaN   NaN
# 2021-04-28   NaN   NaN   NaN
# 2021-04-29   NaN   NaN   NaN

# %%
# df['col_1'] = range(0, len(df))
df['col_1'] = np.random.randint(0, 2, df.shape[0])
#df['col_2'] = np.arange(start=499, stop=-1, step=-1)
df['col_2'] = np.random.randint(0, 100, df.shape[0])
df['col_3'] = np.random.randint(0, 100, df.shape[0])
#df['col_3'] = np.random.randint(0, 2, df.shape[0])

# %%
df
# Out:
#             col_1  col_2  col_3
# 2021-04-20      0     41     47
# 2021-04-21      0     15     46
# 2021-04-22      1     83     85
# 2021-04-23      1     32     44
# 2021-04-24      0     31     57
# 2021-04-25      0     66     99
# 2021-04-26      0     49     71
# 2021-04-27      0     41     75
# 2021-04-28      1     19     65
# 2021-04-29      0     96     63

# %%
df['col_2'] = df['col_2'].where(df['col_1'] == 0, np.nan)

# %%
df
# Out:
#             col_1  col_2  col_3
# 2021-04-20      1    NaN     76
# 2021-04-21      0   70.0     64
# 2021-04-22      0   18.0      5
# 2021-04-23      1    NaN      5
# 2021-04-24      1    NaN     80
# 2021-04-25      0   45.0     11
# 2021-04-26      1    NaN     59
# 2021-04-27      1    NaN     58
# 2021-04-28      1    NaN     91
# 2021-04-29      1    NaN     64

# %%
df = df.where(df['col_1'] == 0, np.nan)

# %%
df
# Out:
#             col_1  col_2  col_3
# 2021-04-20    0.0   41.0   47.0
# 2021-04-21    0.0   15.0   46.0
# 2021-04-22    NaN    NaN    NaN
# 2021-04-23    NaN    NaN    NaN
# 2021-04-24    0.0   31.0   57.0
# 2021-04-25    0.0   66.0   99.0
# 2021-04-26    0.0   49.0   71.0
# 2021-04-27    0.0   41.0   75.0
# 2021-04-28    NaN    NaN    NaN
# 2021-04-29    0.0   96.0   63.0

# %%
dict1 = dict(df['col_1'].value_counts())
print(dict1)
# Out:
# {3: 3, 0: 3, 4: 2, 1: 2}

# %%
df['c1_v'] = df['col_1'].map(dict1)

# %%
df['col1_copy'] = df['col_1']

# %%
df['col1_copy'] = df['col1_copy'].where(df['col_2'] > 25, np.nan)

# %%
dict2 = dict(df['col1_copy'].value_counts())
df['c1_v2'] = df['col1_copy'].map(dict2)

# %%
display(dict1)
display(dict2)
# Out:
# {3: 3, 0: 3, 4: 2, 1: 2}
# {1.0: 2, 0.0: 2, 4.0: 2, 3.0: 1}

# %%
df
# Out:
#             col_1  col_2 col_3  c1_v  col1_copy  c1_v2
# 2021-04-17      4     91   NaN     2        4.0    2.0
# 2021-04-18      3      5   NaN     3        NaN    NaN
# 2021-04-19      3     20   NaN     3        NaN    NaN
# 2021-04-20      0     27   NaN     3        0.0    2.0
# 2021-04-21      3     41   NaN     3        3.0    1.0
# 2021-04-22      1     30   NaN     2        1.0    2.0
# 2021-04-23      4     88   NaN     2        4.0    2.0
# 2021-04-24      1     85   NaN     2        1.0    2.0
# 2021-04-25      0     88   NaN     3        0.0    2.0
# 2021-04-26      0     16   NaN     3        NaN    NaN

# %%
df['col_3'] = df['col_2']/df['c1_v']

# %%
df
# Out:
#             col_1  col_2      col_3  c1_v
# 2021-04-17      4     33  11.000000     3
# 2021-04-18      2     68  17.000000     4
# 2021-04-19      2     79  19.750000     4
# 2021-04-20      1     56  56.000000     1
# 2021-04-21      2      6   1.500000     4
# 2021-04-22      3     61  30.500000     2
# 2021-04-23      3     70  35.000000     2
# 2021-04-24      4     37  12.333333     3
# 2021-04-25      4     25   8.333333     3
# 2021-04-26      2     23   5.750000     4

# %%
df['col_1'].unique()
# Out:
# array([4, 2, 1, 3])

# %%
df['counnt']=df[df['col_2']>25

# %%
df
# Out:
#             col_1  col_2      col_3  c1_v  counnt
# 2021-04-17      4     33  11.000000     3       2
# 2021-04-18      2     68  17.000000     4       2
# 2021-04-19      2     79  19.750000     4       2
# 2021-04-20      1     56  56.000000     1       2
# 2021-04-21      2      6   1.500000     4       2
# 2021-04-22      3     61  30.500000     2       2
# 2021-04-23      3     70  35.000000     2       2
# 2021-04-24      4     37  12.333333     3       2
# 2021-04-25      4     25   8.333333     3       2
# 2021-04-26      2     23   5.750000     4       2

# %%
df['col_1_bins'] = (pd.cut(df['col_1'], bins = 50, precision=0))value_counts_2_bins'] = (pd.cut(df['col_2'], bins = 10, precision=0))

# %%
df.tail()
# Out:
#             col_1  col_2      col_1_bins    col_2_bins
# 2022-08-17    495     29  (489.0, 499.0]  (20.0, 30.0]
# 2022-08-18    496     67  (489.0, 499.0]  (59.0, 69.0]
# 2022-08-19    497     77  (489.0, 499.0]  (69.0, 79.0]
# 2022-08-20    498     58  (489.0, 499.0]  (50.0, 59.0]
# 2022-08-21    499     12  (489.0, 499.0]  (10.0, 20.0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 500 entries, 2021-04-09 to 2022-08-21
# Freq: D
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   col_1       500 non-null    int32
#  1   col_2       500 non-null    int32
#  2   col_1_bins  500 non-null    category
#  3   col_2_bins  500 non-null    category
# dtypes: category(2), int32(2)
# memory usage: 12.5 KB

# %%
df = df.reset_index()

# %%
df.head()
# Out:
#        index  col_1  col_2    col_1_bins    col_2_bins
# 0 2021-04-09      0     35  (-0.0, 10.0]  (30.0, 40.0]
# 1 2021-04-10      1     42  (-0.0, 10.0]  (40.0, 50.0]
# 2 2021-04-11      2     35  (-0.0, 10.0]  (30.0, 40.0]
# 3 2021-04-12      3     38  (-0.0, 10.0]  (30.0, 40.0]
# 4 2021-04-13      4      9  (-0.0, 10.0]  (-0.1, 10.0]

# %%
df2 = df.drop(['index', 'col_1', 'col_2'], axis=1)

# %%
df2.head()
# Out:
#      col_1_bins    col_2_bins
# 0  (-0.0, 10.0]  (30.0, 40.0]
# 1  (-0.0, 10.0]  (40.0, 50.0]
# 2  (-0.0, 10.0]  (30.0, 40.0]
# 3  (-0.0, 10.0]  (30.0, 40.0]
# 4  (-0.0, 10.0]  (-0.1, 10.0]

# %%
df2 = df2.set_index('col_1_bins')

# %%
df3=df2.groupby(['col_1_bins', 'col_2_bins']).size().unstack()

# %%
df3
# Out:
# col_2_bins      (-0.1, 10.0]  (10.0, 20.0]  (20.0, 30.0]  (30.0, 40.0]  \
# col_1_bins
# (-0.0, 10.0]               3             1             0             4
# (10.0, 20.0]               1             1             0             0
# (20.0, 30.0]               4             0             0             0
# (30.0, 40.0]               1             1             2             1
# (40.0, 50.0]               1             1             2             1
# (50.0, 60.0]               3             0             1             1
# (60.0, 70.0]               2             0             0             1
# (70.0, 80.0]               1             0             2             0
# (80.0, 90.0]               2             0             1             3
# (90.0, 100.0]              0             2             1             1
# (100.0, 110.0]             1             2             0             0
# (110.0, 120.0]             3             1             1             2
# ...

# %%
fig_dims = (18, 18)
fig, ax = plt.subplots(figsize=fig_dims)


# point1 = [df['col_1'].iloc[0], df['col_2'].iloc[0]]
# point2 = [df['col_1'].iloc[int(4999)], df['col_2'].iloc[4999]]
x_values1 = [0, 90]
y_values1 = [10,20]
#plt.pcolor(np.array(df), cmap=plt.cm.seismic, vmin=0, vmax=2.0)
plt.plot(x_values1, y_values1, color='red')


hm =sns.heatmap(df3, vmin=0.5, vmax=0.25)

# %%
df['col_3'].iloc[0:100] = 100
df['col_3'].iloc[101:400] = 0
df['col_3'].iloc[401:499] = 100

# %%
df['col_2'].iloc[456]
# Out:
# 13

# %%
df.tail()
# Out:
#             col_1  col_2
# 2022-08-09    495     33
# 2022-08-10    496     55
# 2022-08-11    497     35
# 2022-08-12    498     33
# 2022-08-13    499     39

# %%
bins = np.floor(np.linspace(df.col_1.min(), df.col_1.max(), 50))
groups = df.groupby(pd.cut(df['col_1'], bins)).count()
# groups = df.groupby(np.digitize(df.col_1, bins)).count()
display(groups)
# Out:
#                 col_1  col_2
# col_1
# (0.0, 10.0]        10     10
# (10.0, 20.0]       10     10
# (20.0, 30.0]       10     10
# (30.0, 40.0]       10     10
# (40.0, 50.0]       10     10
# (50.0, 61.0]       11     11
# (61.0, 71.0]       10     10
# (71.0, 81.0]       10     10
# (81.0, 91.0]       10     10
# (91.0, 101.0]      10     10
# (101.0, 112.0]     11     11
# (112.0, 122.0]     10     10
# (122.0, 132.0]     10     10
# (132.0, 142.0]     10     10
# (142.0, 152.0]     10     10
# (152.0, 162.0]     10     10
# (162.0, 173.0]     11     11
# (173.0, 183.0]     10     10
# (183.0, 193.0]     10     10
# (193.0, 203.0]     10     10
# (203.0, 213.0]     10     10
# (213.0, 224.0]     11     11
# (224.0, 234.0]     10     10
# (234.0, 244.0]     10     10
# (244.0, 254.0]     10     10
# (254.0, 264.0]     10     10
# (264.0, 274.0]     10     10
# (274.0, 285.0]     11     11
# (285.0, 295.0]     10     10
# (295.0, 305.0]     10     10
# (305.0, 315.0]     10     10
# ...

# %%
groups.index.rename('values', inplace = True)
groups.reset_index(inplace = True)
display(groups)
# Out:
#             values  col_1  col_2
# 0      (0.0, 10.0]     10     10
# 1     (10.0, 20.0]     10     10
# 2     (20.0, 30.0]     10     10
# 3     (30.0, 40.0]     10     10
# 4     (40.0, 50.0]     10     10
# 5     (50.0, 61.0]     11     11
# 6     (61.0, 71.0]     10     10
# 7     (71.0, 81.0]     10     10
# 8     (81.0, 91.0]     10     10
# 9    (91.0, 101.0]     10     10
# 10  (101.0, 112.0]     11     11
# 11  (112.0, 122.0]     10     10
# 12  (122.0, 132.0]     10     10
# 13  (132.0, 142.0]     10     10
# 14  (142.0, 152.0]     10     10
# 15  (152.0, 162.0]     10     10
# 16  (162.0, 173.0]     11     11
# 17  (173.0, 183.0]     10     10
# 18  (183.0, 193.0]     10     10
# 19  (193.0, 203.0]     10     10
# 20  (203.0, 213.0]     10     10
# 21  (213.0, 224.0]     11     11
# 22  (224.0, 234.0]     10     10
# 23  (234.0, 244.0]     10     10
# 24  (244.0, 254.0]     10     10
# 25  (254.0, 264.0]     10     10
# 26  (264.0, 274.0]     10     10
# ...

# %%
df2 = pd.pivot_table(groups, index = 'col_1')
display(df2)
# Out:
#        col_2
# col_1
# 10        10
# 11        11

# %%
import seaborn as sns
sns.heatmap(df2)

# %%
df

# %%
display(groups)
# Out:
#     col_1  col_2  col_3
# 1      11     11     11
# 2      10     10     10
# 3      10     10     10
# 4      10     10     10
# 5      10     10     10
# 6      11     11     11
# 7      10     10     10
# 8      10     10     10
# 9      10     10     10
# 10     10     10     10
# 11     11     11     11
# 12     10     10     10
# 13     10     10     10
# 14     10     10     10
# 15     10     10     10
# 16     10     10     10
# 17     11     11     11
# 18     10     10     10
# 19     10     10     10
# 20     10     10     10
# 21     10     10     10
# 22     11     11     11
# 23     10     10     10
# 24     10     10     10
# 25     10     10     10
# 26     10     10     10
# 27     10     10     10
# 28     11     11     11
# 29     10     10     10
# 30     10     10     10
# 31     10     10     10
# 32     10     10     10
# 33     11     11     11
# 34     10     10     10
# 35     10     10     10
# 36     10     10     10
# 37     10     10     10
# ...

# %%
bins = [0, 10, 18, 35, 65]
names = ['<2', '2-18', '18-35', '35-65', '65+']

d = dict(enumerate(names, 1))

df['AgeRange'] = np.vectorize(d.get)(np.digitize(df['Age'], bins))

# %%
df['c1_bin'] =

# %%
bins = [0, 2, 18, 35, 65]
names = ['<2', '2-18', '18-35', '35-65', '65+']

d = dict(enumerate(names, 1))

df['AgeRange'] = np.vectorize(d.get)(np.digitize(df['Age'], bins))

# %%
ref_time = todays_date - pd.Timedelta(days = 365)

# %%
ref_time
# Out:
# datetime.date(2020, 3, 31)

# %%
ref_time = pd.to_datetime(ref_time)

# %%
x = (df.index - ref_time).days

# %%
type(x[0])
# Out:
# numpy.int64

# %%
df['Months'] = ((df.index - ref_time).days/30).astype(int)

# %%
type(df['Months'][0])
# Out:
# numpy.float64

# %%
df.head(30)
# Out:
#             col_1  col_2  col_3  Months
# 2021-03-31      0    499      0      12
# 2021-04-01      1    498      1      12
# 2021-04-02      2    497      1      12
# 2021-04-03      3    496      0      12
# 2021-04-04      4    495      0      12
# 2021-04-05      5    494      0      12
# 2021-04-06      6    493      0      12
# 2021-04-07      7    492      1      12
# 2021-04-08      8    491      0      12
# 2021-04-09      9    490      0      12
# 2021-04-10     10    489      0      12
# 2021-04-11     11    488      0      12
# 2021-04-12     12    487      1      12
# 2021-04-13     13    486      1      12
# 2021-04-14     14    485      1      12
# 2021-04-15     15    484      1      12
# 2021-04-16     16    483      0      12
# 2021-04-17     17    482      0      12
# 2021-04-18     18    481      1      12
# 2021-04-19     19    480      1      12
# 2021-04-20     20    479      1      12
# 2021-04-21     21    478      1      12
# ...

# %%
df['Months'].max() - 2
# Out:
# 26

# %%
df['last_2_m'] = df['last_2_m'].where(df['Months'] < (df['Months'].max() - 2), 1)

# %%
df.tail()
# Out:
#             col_1  col_2  col_3
# 2022-08-08    495      4      1
# 2022-08-09    496      3      1
# 2022-08-10    497      2      0
# 2022-08-11    498      1      1
# 2022-08-12    499      0      1

# %%
plt.figure(figsize = (20, 20))
plt.scatter(df['col_1'], df['col_2'], c=df['last_2_m'], marker='x')
plt.xlabel("Col_1")
plt.ylabel("Col_2")
#plt.legend(loc='best', prop={'size': 20})
plt.title('Scatter plot of col_1, col_2 color coded by Month duration')
# Out:
# Text(0.5, 1.0, 'Scatter plot of col_1, col_2 color coded by Month duration')

# %%
df_pivoted = df.pivot("col_1", "col_2", "col_3")

# %%
df_pivoted.tail()
# Out:
# col_2  1    3    4    5    6    7    8    9    10   11   ...  485  487  489  \
# col_1                                                    ...
# 495    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 496    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 497    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 498    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 499    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
#
# col_2  490  491  492  495  496  498  499
# col_1
# 495    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 496    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 497    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 498    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 499    NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 321 columns]

# %% [markdown]
# # Heatmap

# %%
ax = sns.heatmap(df_pivoted)
#plt.show()

# %%
df['label'] = np.where(dt - df['time'] < a, '1','0')

# %%
df.index.iloc[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-125-ea6f91bbd908> in <module>
# ----> 1 df.index.iloc[0]
#
# AttributeError: 'DatetimeIndex' object has no attribute 'iloc'

# %%
plt.figure(figsize = (20, 20))
plt.scatter(df['col_1'], df['col_2'], c=df['col_3'], marker='x')
plt.xlabel("Col_1")
plt.ylabel("Col_2")
#plt.legend(loc='best', prop={'size': 20})
plt.title('Scatter plot of col_1, col_2 color coded by col_3')
# Out:
# Text(0.5, 1.0, 'Scatter plot of col_1, col_2 color coded by col_3')

# %% [markdown]
# ## Scatter plot of col_1 & col_2

# %%
df1 = df[(df['col_3'] < 4) & (df['col_4'] < 4)]

# %%
df1.head()
# Out:
#                      col_1  col_2  col_3  col_4
# 2021-03-25 00:00:00      0    142      0      0
# 2021-03-25 00:02:00      2    219      0      2
# 2021-03-25 00:04:00      4     40      1      2
# 2021-03-25 00:07:00      7    185      2      1
# 2021-03-25 00:09:00      9    121      0      2

# %%
df1['col_4'].nunique()
# Out:
# 4

# %%
df1 = df1.reset_index()

# %%
df1
# Out:
#                   index  col_1  col_2  col_3  col_4
# 0   2021-03-25 00:00:00      0    142      0      0
# 1   2021-03-25 00:02:00      2    219      0      2
# 2   2021-03-25 00:04:00      4     40      1      2
# 3   2021-03-25 00:07:00      7    185      2      1
# 4   2021-03-25 00:09:00      9    121      0      2
# ..                  ...    ...    ...    ...    ...
# 216 2021-03-25 08:14:00    494    404      1      3
# 217 2021-03-25 08:15:00    495    453      0      3
# 218 2021-03-25 08:16:00    496    208      2      2
# 219 2021-03-25 08:18:00    498    354      2      1
# 220 2021-03-25 08:19:00    499    179      3      0
#
# [221 rows x 5 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221 entries, 0 to 220
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   221 non-null    datetime64[ns]
#  1   col_1   221 non-null    int32
#  2   col_2   221 non-null    int32
#  3   col_3   221 non-null    int32
#  4   col_4   221 non-null    int32
# dtypes: datetime64[ns](1), int32(4)
# memory usage: 5.3 KB

# %%
plt.figure(figsize = (20, 20))
plt.plot_date(df1['index'], df1['col_1'], c = 'red', label='col_1')
plt.plot_date(df1['index'], df1['col_2'], c = 'green', label='col_2')
plt.xlabel("Datetime")
plt.ylabel("Cols")
plt.legend(loc='best', prop={'size': 20})
plt.title('Scatter plot of col_1, col_2 based on Datetime')
# Out:
# Text(0.5, 1.0, 'Scatter plot of col_1, col_2 based on Datetime')

# %% [markdown]
# ## Scatter plot of col_1 & col_2 wrt datetime without threshold (color coded)

# %%
df2 = df.reset_index()

# %%
df2.head()
# Out:
#                 index  col_1  col_2  col_3  col_4
# 0 2021-03-25 00:00:00      0    417      5      2
# 1 2021-03-25 00:01:00      1     92      0      0
# 2 2021-03-25 00:02:00      2    415      4      4
# 3 2021-03-25 00:03:00      3    438      1      3
# 4 2021-03-25 00:04:00      4    175      0      1

# %%
df2['col_4'].nunique()
# Out:
# 6

# %%
df2.head()
# Out:
#                 index  col_1  col_2  col_3  col_4
# 0 2021-03-25 00:00:00      0    417      5      2
# 1 2021-03-25 00:01:00      1     92      0      0
# 2 2021-03-25 00:02:00      2    415      4      4
# 3 2021-03-25 00:03:00      3    438      1      3
# 4 2021-03-25 00:04:00      4    175      0      1

# %%
df2['new_col'] = 0
df2['new_col'] = df2['new_col'].where(((df2['col_3'] < 4) & (df2['col_4'] < 4)),1)
#if ((df2['col_3'] < 4) & (df2['col_4'] < 4)):
  #  df2['new_col'] = 0
#else: 
  #  df2['new_col'] = 1

# %%
df2.head()
# Out:
#                 index  col_1  col_2  col_3  col_4  new_col
# 0 2021-03-25 00:00:00      0    417      5      2        1
# 1 2021-03-25 00:01:00      1     92      0      0        0
# 2 2021-03-25 00:02:00      2    415      4      4        1
# 3 2021-03-25 00:03:00      3    438      1      3        0
# 4 2021-03-25 00:04:00      4    175      0      1        0

# %%
df2['new_col'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df2.index[0]
# Out:
# 0

# %%
plt.figure(figsize = (20, 20))
plt.scatter(df2['index'], df2['col_1'], c=df2['new_col'], marker='x')
plt.scatter(df2['index'], df2['col_2'], c=df2['new_col'], marker='s')
plt.xlabel("Datetime")
plt.ylabel("Cols")
#plt.legend(loc=1, prop={'size': 20})
plt.title('Scatter plot of col_1, col_2 based on Datetime with condition')
# Out:
# Text(0.5, 1.0, 'Scatter plot of col_1, col_2 based on Datetime with condition')

# %%
df1 = pd.DataFrame(np.random.random((10,10)), columns=["a","b","c","d","e","f","g","h","i","j"])

# %%
df1
# Out:
#           a         b         c         d         e         f         g  \
# 0  0.064834  0.539883  0.027499  0.847351  0.788956  0.814507  0.213579
# 1  0.788946  0.079003  0.209864  0.520944  0.088474  0.031372  0.548188
# 2  0.366114  0.364567  0.411979  0.007047  0.154498  0.246242  0.931198
# 3  0.051459  0.043825  0.317177  0.516413  0.980381  0.799074  0.972919
# 4  0.820956  0.004706  0.125245  0.400138  0.277099  0.270864  0.121809
# 5  0.662621  0.998365  0.071139  0.805493  0.224126  0.181205  0.668377
# 6  0.118810  0.097425  0.312579  0.470889  0.166205  0.920681  0.066791
# 7  0.420866  0.232920  0.940130  0.758462  0.639889  0.230822  0.044681
# 8  0.291078  0.422212  0.857594  0.380725  0.129493  0.551972  0.319412
# 9  0.286854  0.038577  0.958274  0.950389  0.398106  0.713924  0.070257
#
#           h         i         j
# 0  0.967776  0.716018  0.894658
# 1  0.387600  0.258407  0.192252
# 2  0.536626  0.967516  0.730182
# 3  0.398609  0.771378  0.864877
# ...

# %%
df1['a']
# Out:
# 0    0.064834
# 1    0.788946
# 2    0.366114
# 3    0.051459
# 4    0.820956
# 5    0.662621
# 6    0.118810
# 7    0.420866
# 8    0.291078
# 9    0.286854
# Name: a, dtype: float64

# %%
df1.append(pd.Series(), ignore_index=True)
# Out:
# C:\Users\Trayan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   """Entry point for launching an IPython kernel.
#            a         b         c         d         e         f         g  \
# 0   0.064834  0.539883  0.027499  0.847351  0.788956  0.814507  0.213579
# 1   0.788946  0.079003  0.209864  0.520944  0.088474  0.031372  0.548188
# 2   0.366114  0.364567  0.411979  0.007047  0.154498  0.246242  0.931198
# 3   0.051459  0.043825  0.317177  0.516413  0.980381  0.799074  0.972919
# 4   0.820956  0.004706  0.125245  0.400138  0.277099  0.270864  0.121809
# 5   0.662621  0.998365  0.071139  0.805493  0.224126  0.181205  0.668377
# 6   0.118810  0.097425  0.312579  0.470889  0.166205  0.920681  0.066791
# 7   0.420866  0.232920  0.940130  0.758462  0.639889  0.230822  0.044681
# ...
